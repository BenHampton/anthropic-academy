# %%
# Install Dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.97.0)
# Requirement already satisfied: python-dotenv in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (2.13.2)
# Requirement already satisfied: sniffio in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, Json or a plain Regex
* Do not add any comments or commentary or explanation 
"""
    
    messages = []

    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])

    return output

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []

    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    
    eval_text = chat(messages, stop_sequences=["```"])

    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    # weaknesses = model_grade["weaknesses"]
    # strengths = model_grade["strengths"]

    syntax_score = grade_syntax(output, test_case)
    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
        # "weaknesses": weaknesses,
        # "strengths": strengths
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_scrore = mean([result["score"] for result in results])
    print(f"Average score: {average_scrore}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nfrom typing import Dict\n\ndef parse_s3_uri(s3_uri: str) -> Dict[str, str]:\n    pattern = r's3://([^/]+)(?:/(.+)/([^/]+))?$|s3://([^/]+)(?:/([^/]+))?$'\n    \n    match = re.match(r's3://([^/]+)(?:/(.*))?$', s3_uri)\n    if not match:\n        raise ValueError(\"Invalid S3 URI format\")\n    \n    bucket = match.group(1)\n    path_and_file = match.group(2) or \"\"\n    \n    if not path_and_file:\n        return {\n            \"bucket\": bucket,\n            \"folder_path\": \"\",\n            \"file_name\": \"\"\n        }\n    \n    last_slash = path_and_file.rfind('/')\n    \n    if last_slash == -1:\n        return {\n            \"bucket\": bucket,\n            \"folder_path\": \"\",\n            \"file_name\": path_and_file\n        }\n    \n    folder_path = path_and_file[:last_slash]\n    file_name = path_and_file[last_slash + 1:]\n    \n    return {\n        \"bucket\": bucket,\n        \"folder_path\": folder_path,\n        \"file_name\": file_name\n    }\n\nresult = parse_s3_uri('s3://my-bucket/folder/subfolder/file.txt')\nprint(result)\n",
#     "test_case": {
#       "task": "Parse an AWS S3 object key to extract the bucket name, folder path, and file name from a full S3 URI like 's3://my-bucket/folder/subfolder/file.txt'",
#       "format": "regex"
#     },
#     "score": 8.5,
#     "reasoning": "The solution effectively solves the core problem with a straightforward approach. The regex pattern used is clean and the fallback logic for finding the last slash is reliable. However, the unused pattern variable suggests incomplete code cleanup. The function would benefit from more comprehensive input validation and documentation. The core functionality is correct for standard S3 URIs but lacks robustness for edge cases and AWS-specific URI variations."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for AWS Lambda function with execution role and environment variables\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"LambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"MyLambdaFunction\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.lambda_handler\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\"\n        },\n        \"Environment\": {\n          \"Variables\": {\n            \"ENV\": \"production\",\n            \"DEBUG\": \"false\",\n            \"API_ENDPOINT\": \"https://api.example.com\",\n            \"LOG_LEVEL\": \"INFO\"\n          }\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"LambdaFunction\"\n      }\n    },\n    \"ExecutionRoleArn\": {\n      \"Description\": \"ARN of the Lambda execution role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaExecutionRole\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template that defines an AWS Lambda function with basic execution role and environment variables",
#       "format": "json"
#     },
#     "score": 8.5,
#     "reasoning": "The template demonstrates solid understanding of CloudFormation fundamentals and correctly implements the core requirements: Lambda function, execution role, and environment variables. The IAM configuration is appropriate and outputs are well-designed. However, it lacks production-ready practices such as parameterization and S3-based code deployment. The inline code approach is acceptable for examples but limits practical utility. The missing timeout/memory properties are minor omissions but represent incomplete function configuration."
#   },
#   {
#     "output": "\nimport json\nimport re\n\ndef extract_resource_arns(policy_document: str) -> list[str]:\n    \"\"\"\n    Extracts all Resource ARNs from an AWS IAM policy document JSON string.\n    \n    Args:\n        policy_document: A JSON string containing an AWS IAM policy\n        \n    Returns:\n        A list of all Resource ARNs found in the policy\n    \"\"\"\n    try:\n        policy = json.loads(policy_document)\n    except json.JSONDecodeError:\n        return []\n    \n    arns = []\n    \n    def extract_arns_from_obj(obj):\n        if isinstance(obj, dict):\n            for key, value in obj.items():\n                if key.lower() == 'resource':\n                    if isinstance(value, str):\n                        arns.append(value)\n                    elif isinstance(value, list):\n                        arns.extend(value)\n                else:\n                    extract_arns_from_obj(value)\n        elif isinstance(obj, list):\n            for item in obj:\n                extract_arns_from_obj(item)\n    \n    extract_arns_from_obj(policy)\n    return arns\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM policy document as a JSON string and returns a list of all Resource ARNs mentioned in it",
#       "format": "python"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly solves the core requirement of extracting Resource ARNs from IAM policy documents through effective recursion and handles common input variations. However, it has notable quality issues: the case-insensitive key matching deviates from AWS standards, there's an unused import suggesting incomplete code, and it doesn't validate that extracted values are legitimate ARNs. For production use, these issues should be addressed, particularly validating ARN format and removing the unnecessary regex import."
#   }
# ]
