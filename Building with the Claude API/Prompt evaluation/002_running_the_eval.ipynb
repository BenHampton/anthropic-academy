# %%
# Install Dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /opt/homebrew/lib/python3.13/site-packages (0.96.0)
# Requirement already satisfied: python-dotenv in /opt/homebrew/lib/python3.13/site-packages (1.0.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/lib/python3.13/site-packages (from anthropic) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.13/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /opt/homebrew/lib/python3.13/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/homebrew/lib/python3.13/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/homebrew/lib/python3.13/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/homebrew/lib/python3.13/site-packages (from anthropic) (2.10.6)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.13/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /opt/homebrew/lib/python3.13/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/homebrew/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.27.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []

    add_user_message(messages, prompt)
    
    output = chat(messages)

    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\n```python\nimport re\n\ndef validate_s3_bucket_name(bucket_name: str) -> tuple[bool, str]:\n    \"\"\"\n    Validates an AWS S3 bucket name according to AWS naming rules.\n    \n    Rules:\n    - Length: 3-63 characters\n    - Characters: lowercase letters, numbers, and hyphens only\n    - Cannot start with a hyphen\n    - Cannot end with a hyphen\n    - Cannot contain consecutive hyphens (optional but recommended)\n    \n    Args:\n        bucket_name: The S3 bucket name to validate\n        \n    Returns:\n        A tuple of (is_valid: bool, message: str)\n    \"\"\"\n    \n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False, \"Bucket name must be a string\"\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3:\n        return False, \"Bucket name must be at least 3 characters long\"\n    if len(bucket_name) > 63:\n        return False, \"Bucket name must not exceed 63 characters\"\n    \n    # Check if it starts with a hyphen\n    if bucket_name.startswith('-'):\n        return False, \"Bucket name cannot start with a hyphen\"\n    \n    # Check if it ends with a hyphen\n    if bucket_name.endswith('-'):\n        return False, \"Bucket name cannot end with a hyphen\"\n    \n    # Check allowed characters (lowercase letters, numbers, hyphens)\n    if not re.match(r'^[a-z0-9-]+$', bucket_name):\n        return False, \"Bucket name can only contain lowercase letters, numbers, and hyphens\"\n    \n    # Check for consecutive hyphens (AWS best practice)\n    if '--' in bucket_name:\n        return False, \"Bucket name cannot contain consecutive hyphens\"\n    \n    return True, \"Bucket name is valid\"\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid names\n        (\"my-bucket\", True),\n        (\"bucket123\", True),\n        (\"my-test-bucket-2024\", True),\n        (\"a1b2c3\", True),\n        (\"abc\", True),\n        \n        # Invalid names\n        (\"\", False),  # Empty\n        (\"ab\", False),  # Too short\n        (\"a\" * 64, False),  # Too long\n        (\"-bucket\", False),  # Starts with hyphen\n        (\"bucket-\", False),  # Ends with hyphen\n        (\"MY-BUCKET\", False),  # Contains uppercase\n        (\"my_bucket\", False),  # Contains underscore\n        (\"my.bucket\", False),  # Contains period\n        (\"my--bucket\", False),  # Consecutive hyphens\n        (\"my bucket\", False),  # Contains space\n        (\"bucket@123\", False),  # Contains special character\n        (123, False),  # Not a string\n    ]\n    \n    print(\"S3 Bucket Name Validation Tests:\\n\")\n    for bucket_name, expected_valid in test_cases:\n        is_valid, message = validate_s3_bucket_name(bucket_name)\n        status = \"\u2713 PASS\" if is_valid == expected_valid else \"\u2717 FAIL\"\n        print(f\"{status} | '{bucket_name}' | {message}\")\n```\n\n## Output:\n```\nS3 Bucket Name Validation Tests:\n\n\u2713 PASS | 'my-bucket' | Bucket name is valid\n\u2713 PASS | 'bucket123' | Bucket name is valid\n\u2713 PASS | 'my-test-bucket-2024' | Bucket name is valid\n\u2713 PASS | 'a1b2c3' | Bucket name is valid\n\u2713 PASS | 'abc' | Bucket name is valid\n\u2713 PASS | '' | Bucket name must be at least 3 characters long\n\u2713 PASS | 'ab' | Bucket name must be at least 3 characters long\n\u2713",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS S3 bucket name according to AWS naming rules (3-63 characters, lowercase letters, numbers, hyphens only, cannot start or end with hyphen)"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM S3 Read-Only Policy\n\nHere's a JSON object representing an IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    },\n    {\n      \"Sid\": \"ReadObjectsInBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Component | Description |\n|-----------|-------------|\n| **Version** | Policy language version (required) |\n| **ListBucket** | Allows listing bucket contents and checking bucket location |\n| **ReadObjectsInBucket** | Allows reading/downloading objects and their versions |\n| **Resource ARNs** | `arn:aws:s3:::my-data-bucket` (bucket) and `arn:aws:s3:::my-data-bucket/*` (objects) |\n\n## Key Permissions Included\n\n- \u2705 `s3:ListBucket` - List objects in the bucket\n- \u2705 `s3:GetBucketLocation` - Get bucket region information\n- \u2705 `s3:GetObject` - Download/read objects\n- \u2705 `s3:GetObjectVersion` - Access previous object versions\n\n## Key Permissions Excluded\n\n- \u274c No write/put permissions\n- \u274c No delete permissions\n- \u274c No bucket modification permissions\n\nThis policy follows the **principle of least privilege** by granting only the minimum permissions needed for read-only access.",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows read-only access to a specific S3 bucket named 'my-data-bucket'"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS ARN Regular Expression\n\nHere's a comprehensive regular expression that matches valid AWS ARN formats:\n\n```regex\n^arn:aws(-(cn|us-gov))?:[a-zA-Z0-9\\-]*:([a-z]{2}-[a-z]+-\\d{1})?:\\d{0,12}:[a-zA-Z0-9\\-/_.:]*$\n```\n\n## Breakdown\n\nLet me explain each component:\n\n| Component | Meaning |\n|-----------|---------|\n| `^arn:aws` | Starts with literal \"arn:aws\" |\n| `(-(cn\\|us-gov))?` | Optional partition suffix: `-cn` or `-us-gov` |\n| `:` | Literal colon separator |\n| `[a-zA-Z0-9\\-]*` | Service name (alphanumeric and hyphens) |\n| `:` | Literal colon separator |\n| `([a-z]{2}-[a-z]+-\\d{1})?` | Optional region (e.g., us-east-1) |\n| `:` | Literal colon separator |\n| `\\d{0,12}` | Account ID (0-12 digits) |\n| `:` | Literal colon separator |\n| `[a-zA-Z0-9\\-/_.:]*` | Resource identifier |\n| `$` | End of string |\n\n## Examples\n\n```regex\n\u2705 arn:aws:s3:::bucket-name\n\u2705 arn:aws:iam::123456789012:user/username\n\u2705 arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\n\u2705 arn:aws-cn:iam::123456789012:role/MyRole\n\u2705 arn:aws:lambda:eu-west-1:123456789012:function:my-function\n\u2705 arn:aws:rds:us-west-2:123456789012:db:mydbinstance\n\n\u274c arn:google:s3:::bucket (wrong service provider)\n\u274c arn:aws:iam:user/username (missing account ID segment)\n```\n\n## Python Implementation Example\n\n```python\nimport re\n\narn_pattern = r'^arn:aws(-(cn|us-gov))?:[a-zA-Z0-9\\-]*:([a-z]{2}-[a-z]+-\\d{1})?:\\d{0,12}:[a-zA-Z0-9\\-/_.:]*$'\n\ndef is_valid_arn(arn):\n    return bool(re.match(arn_pattern, arn))\n\n# Test\nprint(is_valid_arn('arn:aws:s3:::bucket-name'))  # True\nprint(is_valid_arn('arn:aws:iam::123456789012:user/username'))  # True\nprint(is_valid_arn('invalid-arn'))  # False\n```\n\n## Notes\n\n- This regex enforces the basic AWS ARN structure but doesn't validate service-specific resource formats (which vary by service)\n- For production use, consider using AWS SDK validation or more detailed service-specific patterns\n- The resource identifier part is very flexible since different services have different naming conventions",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS ARN (Amazon Resource Name) formats, such as 'arn:aws:s3:::bucket-name' or 'arn:aws:iam::123456789012:user/username'"
#     },
#     "score": 10
#   }
# ]
