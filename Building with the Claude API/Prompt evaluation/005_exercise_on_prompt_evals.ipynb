# %%
# Install Dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.97.0)
# Requirement already satisfied: python-dotenv in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (2.13.2)
# Requirement already satisfied: sniffio in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\benja\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, Json or a plain Regex
* Do not add any comments or commentary or explanation 
"""
    
    messages = []

    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])

    return output

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<ceriteria>
{test_case["solution_criteria"]}
</ceriteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []

    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    
    eval_text = chat(messages, stop_sequences=["```"])

    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    # weaknesses = model_grade["weaknesses"]
    # strengths = model_grade["strengths"]

    syntax_score = grade_syntax(output, test_case)
    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
        # "weaknesses": weaknesses,
        # "strengths": strengths
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_scrore = mean([result["score"] for result in results])
    print(f"Average score: {average_scrore}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 5.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport json\n\ndef parse_cloudwatch_log(log_entry):\n    pattern = r'\\[([^\\]]+)\\]\\s+\\[([^\\]]+)\\]\\s+(.*)'\n    match = re.match(pattern, log_entry)\n    \n    if match:\n        return {\n            \"timestamp\": match.group(1),\n            \"level\": match.group(2),\n            \"message\": match.group(3)\n        }\n    return None\n\n# Example usage:\nlog_entry = \"[2024-01-15T10:30:45Z] [ERROR] Connection timeout occurred\"\nresult = parse_cloudwatch_log(log_entry)\nprint(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudWatch log entry and extract the timestamp, log level, and message. The log format is: '[TIMESTAMP] [LEVEL] MESSAGE'",
#       "format": "regex",
#       "solution_criteria": "The regex must correctly capture three groups: timestamp, log level, and message. Should handle timestamps like '2024-01-15T10:30:45Z' and levels like 'INFO', 'ERROR', 'WARN'"
#     },
#     "score": 3.5,
#     "reasoning": "The solution meets the core requirement of parsing the specified log format and correctly extracts the three components using an appropriate regex pattern. However, it lacks robustness through validation and comprehensive testing. For a production AWS logging solution, it should validate that timestamps conform to ISO 8601 format and log levels match expected CloudWatch values (INFO, WARN, ERROR, etc.). The implementation is functional but would benefit from defensive programming practices and test coverage."
#   },
#   {
#     "output": "\nimport re\n\ndef validate_s3_bucket_name(bucket_name: str) -> bool:\n    \"\"\"\n    Validates an AWS S3 bucket name according to AWS naming rules.\n    \n    Rules:\n    - 3-63 characters\n    - lowercase letters, numbers, hyphens only\n    - cannot start or end with hyphen\n    - cannot contain consecutive hyphens\n    \n    Args:\n        bucket_name: The bucket name to validate\n    \n    Returns:\n        True if valid, False otherwise\n    \"\"\"\n    if not isinstance(bucket_name, str):\n        return False\n    \n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    if bucket_name.startswith('-') or bucket_name.endswith('-'):\n        return False\n    \n    if '--' in bucket_name:\n        return False\n    \n    if not re.match(r'^[a-z0-9-]+$', bucket_name):\n        return False\n    \n    return True\n",
#     "test_case": {
#       "task": "Create a Python function that validates an AWS S3 bucket name according to AWS naming rules: 3-63 characters, lowercase letters, numbers, hyphens only, cannot start or end with hyphen, cannot contain consecutive hyphens",
#       "format": "python",
#       "solution_criteria": "Function should return True for valid bucket names and False for invalid ones. Must handle all AWS naming constraints. Should be a single function with clear logic"
#     },
#     "score": 9.0,
#     "reasoning": "The solution accurately validates all AWS S3 bucket naming constraints. Each rule is properly checked: length (3-63), lowercase/numbers/hyphens only, no leading/trailing hyphens, and no consecutive hyphens. Type safety is included. The main inefficiency is the regex pattern `^[a-z0-9-]+$` which duplicates the character set validation already performed by the character matching check. The individual checks before the regex are sufficient and more efficient. The code is correct and would pass functional requirements but could be optimized."
#   },
#   {
#     "output": "\nimport json\n\nlambda_config = {\n    \"FunctionName\": \"myLambdaFunction\",\n    \"Runtime\": \"python3.11\",\n    \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n    \"Handler\": \"index.handler\",\n    \"Timeout\": 30,\n    \"MemorySize\": 256,\n    \"Environment\": {\n        \"Variables\": {\n            \"DB_HOST\": \"db.example.com\",\n            \"DB_PORT\": \"5432\",\n            \"DB_USERNAME\": \"admin\",\n            \"LOG_GROUP_NAME\": \"/aws/lambda/myLambdaFunction\",\n            \"LOG_RETENTION_DAYS\": \"7\"\n        }\n    },\n    \"LoggingConfig\": {\n        \"LogGroup\": \"/aws/lambda/myLambdaFunction\",\n        \"LogFormat\": \"JSON\"\n    }\n}\n\nprint(json.dumps(lambda_config, indent=2))\n",
#     "test_case": {
#       "task": "Generate a JSON configuration object for an AWS Lambda function with environment variables for database connection (host, port, username) and CloudWatch logging settings (log group name and retention days)",
#       "format": "json",
#       "solution_criteria": "JSON must be valid and include nested objects for environment variables and logging configuration. Should use realistic AWS naming conventions and include placeholder values"
#     },
#     "score": 3.5,
#     "reasoning": "The solution correctly generates valid JSON with the required nested structure for environment variables and logging configuration using realistic AWS conventions. However, it has practical limitations: the string-based numeric values could cause application-level issues, the approach to storing database credentials is insecure, and the logging configuration doesn't fully address how to actually set CloudWatch log retention (which typically requires a separate PutRetentionPolicy API call). Despite these concerns, it meets the core technical requirements of the task."
#   }
# ]
