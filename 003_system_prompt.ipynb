# %%
# Install Dependencies
# %pip install anthropic python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
# Helper functions 

def add_user_message(message, text):
    user_message = { "role": "user", "content": text}
    message.append(user_message)

def add_assistant_message(message, text):
    assistant_message = { "role": "assistant", "content": text}
    message.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system
        
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system = """
    You are a Python engineer who writes very concise code.
    """

add_user_message(messages, "Write a Python functino that check a string for duplicate characters?")
answer = chat(messages, system=system)

answer
# Out:
# '## Check String for Duplicate Characters\n\n```python\ndef has_duplicates(s: str) -> bool:\n    """Returns True if the string contains duplicate characters, False otherwise."""\n    return len(s) != len(set(s))\n```\n\n### Examples\n\n```python\nprint(has_duplicates("hello"))   # True  (\'l\' appears twice)\nprint(has_duplicates("world"))   # False (all unique)\nprint(has_duplicates("python"))  # False (all unique)\nprint(has_duplicates("abcabc"))  # True  (a, b, c repeated)\n```\n\n### Bonus: Get the Actual Duplicates\n\n```python\ndef get_duplicates(s: str) -> set:\n    """Returns a set of duplicate characters in the string."""\n    seen = set()\n    return {char for char in s if char in seen or seen.add(char)}\n\nprint(get_duplicates("hello"))   # {\'l\'}\nprint(get_duplicates("abcabc"))  # {\'a\', \'b\', \'c\'}\n```\n\n### How It Works\n| Function | Approach | Time | Space |\n|----------|----------|------|-------|\n| `has_duplicates` | Compares string length to set length | O(n)
# ...
